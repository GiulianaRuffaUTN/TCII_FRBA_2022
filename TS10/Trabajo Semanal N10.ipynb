# %% [markdown]
# # UNIVERSIDAD TECNOLÓGICA NACIONAL

# %% [markdown]
# # Facultad Regional Buenos Aires

# %% [markdown]
# ## Teoría de los Circuitos II

# %% [markdown]
# ## Año 2022

# %% [markdown]
# ### Trabajo Semanal Nº10

# %% [markdown]
# ### Profesor: Mariano Llamedo Soria

# %% [markdown]
# ### Ayudante: Eugenia Ipar

# %% [markdown]
# ### Giuliana Ruffa (Legajo: 1774463)

# %% [markdown]
# ###### Consigna 1:

# %% [markdown]
# ![Consigna%201-2.png](attachment:Consigna%201-2.png)

# %% [markdown]
# ###### Consigna 2:

# %% [markdown]
# ![Consigna%202.png](attachment:Consigna%202.png)

# %% [markdown]
# ###### Resolución:

# %% [markdown]
# ###### Ejercicios 1 y 2:

# %% [markdown]
# Desarrollo algebráico:

# %%
from IPython.display import IFrame
IFrame("./TS10Final.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./TS10Final.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
