# %% [markdown]
# # UNIVERSIDAD TECNOLÓGICA NACIONAL

# %% [markdown]
# # Facultad Regional Buenos Aires

# %% [markdown]
# ## Teoría de los Circuitos II

# %% [markdown]
# ## Año 2022

# %% [markdown]
# ### Trabajo Semanal Nº2

# %% [markdown]
# ### Profesor: Mariano Llamedo Soria

# %% [markdown]
# ### Ayudante: Eugenia Ipar

# %% [markdown]
# ### Giuliana Ruffa (Legajo: 1774463)

# %% [markdown]
# ###### Consigna:

# %% [markdown]
# Para  la siguiente red se pide:

# %% [markdown]
# ![Consigna.png](attachment:Consigna.png)

# %% [markdown]
# 1) Hallar la transferencia T en función de Wo y Q.
#
# 2) Obtener el valor de los componentes del circuito de forma tal que Wo = 1 y Q = 3.
#
# 3) Ajustar el valor de R1 de forma tal que (T(0)| = 20 dB.

# %% [markdown]
# ###### Resolución:

# %% [markdown]
# Desarrollo algebráico:

# %%
from IPython.display import IFrame
IFrame("./TS2V3.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./TS2V3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# - Simulación numérica: módulo, fase, diagrama de polos y ceros y retardo de grupo:

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})


# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti

num = np.array ([0, 0, -10 ])
den = np.array ([1, 1/3, 1 ])

rf = sig.TransferFunction(num,den)
pretty_print_lti(rf)

    
analyze_sys(rf, 'Topología')
# Out:
# /Users/giulianaruffa/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/filter_design.py:1631: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   warnings.warn("Badly conditioned filter coefficients (numerator): the "
# $\displaystyle \frac{-10 }{s^2 + s \,\, 0.3333 +   1 }$

# %%
   # Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})


# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti

num = np.array ([0, 0, -10 ])
den = np.array ([1, 1.4142, 1 ])

rf = sig.TransferFunction(num,den)
pretty_print_lti(rf)

    
analyze_sys(rf, 'Topología - Butterworth')
# Out:
# /Users/giulianaruffa/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/filter_design.py:1631: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   warnings.warn("Badly conditioned filter coefficients (numerator): the "
# $\displaystyle \frac{-10 }{s^2 + s \,\, 1.414 +   1 }$

# %% [markdown]
# - Simulación circuital: módulo y fase.

# %% [markdown]
# Planteamos la topología inicial:

# %% [markdown]
# ![Circuito.png](attachment:Circuito.png)

# %% [markdown]
# Y obtenemos la siguiente transferencia:

# %% [markdown]
# • Señal de salida: ${V_2 \over V_1} = f (f), en \; dB$

# %% [markdown]
# ![T1%20dB.png](attachment:T1%20dB.png)

# %% [markdown]
# • Señal de salida: ${V_2 \over V_1} = f (f), lineal $

# %% [markdown]
# ![T1%20Lin.png](attachment:T1%20Lin.png)

# %% [markdown]
# Luego, planteamos la topología con transferencia Butterworth: cambiamos el valor de $ {R_{2}} = {1 \over \sqrt{2}} $

# %% [markdown]
# ![Circuito%202.png](attachment:Circuito%202.png)

# %% [markdown]
# • Señal de salida: ${V_2 \over V_1} = f (f), en \; dB$

# %% [markdown]
# ![T2%20dB.png](attachment:T2%20dB.png)

# %% [markdown]
# • Señal de salida: ${V_2 \over V_1} = f (f), lineal $

# %% [markdown]
# ![T2%20Lin.png](attachment:T2%20Lin.png)

# %% [markdown]
# Observamos que se respeta la máxima planicidad en la banda de paso.
