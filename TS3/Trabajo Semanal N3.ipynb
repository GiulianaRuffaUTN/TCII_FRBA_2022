# %% [markdown]
# # UNIVERSIDAD TECNOLÓGICA NACIONAL

# %% [markdown]
# # Facultad Regional Buenos Aires

# %% [markdown]
# ## Teoría de los Circuitos II

# %% [markdown]
# ## Año 2022

# %% [markdown]
# ### Trabajo Semanal Nº3

# %% [markdown]
# ### Profesor: Mariano Llamedo Soria

# %% [markdown]
# ### Ayudante: Eugenia Ipar

# %% [markdown]
# ### Giuliana Ruffa (Legajo: 1774463)

# %% [markdown]
# ###### Consigna:

# %% [markdown]
# A partir de la siguiente plantilla, sabiendo que:

# %% [markdown]
# ![Consigna.png](attachment:Consigna.png)

# %% [markdown]
# 1) Obtener polos y ceros para máxima planicidad en la banda de paso.
#
# 2) Comparar con los polos obtenidos en el ejercicio 3.3. (Este NO! para la TS3, si para el TP2)
#
# 3) Implementar el circuito con estructuras pasivas adaptadas mediante buffers.
#
# 4) Utilizando una norma de impedancia ZN = 1K, obtenga el valor de los componentes.
#
# 5) Active las bobinas utilizando una estructura con OPAMPs.

# %% [markdown]
# ###### Resolución:

# %% [markdown]
# Desarrollo algebráico:

# %%
from IPython.display import IFrame
IFrame("./TS3Final.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./TS3Final.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# - Simulación numérica: módulo, fase, diagrama de polos y ceros y retardo de grupo:

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})


# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti

num = np.array ([1, 0, 0, 0, 0 ])
den = np.array ([1, 2.2, 2.43, 1.57, 0.51 ])

rf = sig.TransferFunction(num,den)
pretty_print_lti(rf)

    
analyze_sys(rf, 'Pasa Altos')
# Out:
# $\displaystyle \frac{s^4 }{s^4 + s^3 \,\, 2.2 + s^2 \,\, 2.43 + s \,\, 1.57 + 0.51 }$

# %% [markdown]
# - Simulación circuital: módulo y fase.

# %% [markdown]
# Planteamos:

# %% [markdown]
# ![Circuito.png](attachment:Circuito.png)

# %% [markdown]
# Y obtenemos la siguiente transferencia:

# %% [markdown]
# • Señal de salida: ${V_2 \over V_1} = f (f), en \; dB$

# %% [markdown]
# ![Rta%20en%20Frecuencia%20dB.png](attachment:Rta%20en%20Frecuencia%20dB.png)

# %% [markdown]
# • Señal de salida: ${V_2 \over V_1} = f (f), lineal $

# %% [markdown]
# ![Rta%20en%20Frecuencia%20Lin.png](attachment:Rta%20en%20Frecuencia%20Lin.png)

# %% [markdown]
# Observamos que se respeta la máxima planicidad en la banda de paso.
