# %% [markdown]
# # UNIVERSIDAD TECNOLÓGICA NACIONAL

# %% [markdown]
# # Facultad Regional Buenos Aires

# %% [markdown]
# ## Teoría de los Circuitos II

# %% [markdown]
# ## Año 2022

# %% [markdown]
# ### Trabajo Semanal Nº13

# %% [markdown]
# ### Profesor: Mariano Llamedo Soria

# %% [markdown]
# ### Ayudante: Eugenia Ipar

# %% [markdown]
# ### Giuliana Ruffa (Legajo: 1774463)

# %% [markdown]
# ###### Consigna 1:

# %% [markdown]
# ![Consigna%201.png](attachment:Consigna%201.png)

# %% [markdown]
# ###### Consigna 2:

# %% [markdown]
# ![Consigna%202.png](attachment:Consigna%202.png)

# %% [markdown]
# Extra:

# %% [markdown]
# ![Extra.png](attachment:Extra.png)

# %% [markdown]
# ###### Resolución:

# %% [markdown]
# ###### Ejercicio 1:

# %% [markdown]
# Desarrollo algebráico:

# %%
from IPython.display import IFrame
IFrame("./TS13-Ej1Final.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./TS13-Ej1Final.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ###### Ejercicio 1: Simulación Circuital

# %% [markdown]
# Agregada en el repositorio.

# %% [markdown]
# ###### Ejercicio 2:

# %%
from IPython.display import IFrame
IFrame("./TS13-Ej2Final.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./TS13-Ej2Final.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ###### Ejercicio 2: Simulación Circuital

# %% [markdown]
# Agregada en el repositorio.

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})


# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti

num = np.array ([1, 0, 9])
den = np.array ([1, 0, 2, 0])

rf = sig.TransferFunction(num,den)
pretty_print_lti(rf)

    
analyze_sys(rf, 'Ej2')
# Out:
# $\displaystyle \frac{s^2 +   9 }{s^3 + s \,\,   2 }$

# %% [markdown]
# ###### Ejercicio 2: Simulación Numérica
