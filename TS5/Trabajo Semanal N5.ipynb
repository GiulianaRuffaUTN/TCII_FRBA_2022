# %% [markdown]
# # UNIVERSIDAD TECNOLÓGICA NACIONAL

# %% [markdown]
# # Facultad Regional Buenos Aires

# %% [markdown]
# ## Teoría de los Circuitos II

# %% [markdown]
# ## Año 2022

# %% [markdown]
# ### Trabajo Semanal Nº5

# %% [markdown]
# ### Profesor: Mariano Llamedo Soria

# %% [markdown]
# ### Ayudante: Eugenia Ipar

# %% [markdown]
# ### Giuliana Ruffa (Legajo: 1774463)

# %% [markdown]
# ###### Consigna:

# %%
from IPython.display import IFrame
IFrame("./Ejercicios.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./Ejercicios.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ###### Resolución:

# %% [markdown]
# ###### Ejercicio 1:

# %% [markdown]
# Desarrollo algebráico:

# %%
from IPython.display import IFrame
IFrame("./TS5Ej1Final.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./TS5Ej1Final.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ###### Ejercicio 2:

# %% [markdown]
# Desarrollo algebráico:

# %%
from IPython.display import IFrame
IFrame("./TS5Ej2Final.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./TS5Ej2Final.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# - Simulación numérica: módulo, fase, diagrama de polos y ceros y retardo de grupo:

# %% [markdown]
# 2) A:

# %%
# A

# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})


# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti

num = np.array ([1/4, 0, 1 ])
den = np.array ([1, 1.4142, 1 ])

rf = sig.TransferFunction(num,den)
pretty_print_lti(rf)

    
analyze_sys(rf, 'A')
# Out:
# $\displaystyle \frac{s^2 \,\, 0.25 +   1 }{s^2 + s \,\, 1.414 +   1 }$

# %% [markdown]
# 2) B:

# %%
#B

# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})


# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti

num = np.array ([1, 0.707, 1 ])
den = np.array ([1, 1.4142, 1 ])

rf = sig.TransferFunction(num,den)
pretty_print_lti(rf)

    
analyze_sys(rf, 'B')
# Out:
# $\displaystyle \frac{s^2 + s \,\, 0.707 +   1 }{s^2 + s \,\, 1.414 +   1 }$

# %% [markdown]
# 2) C:

# %%
#C 
    
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})


# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti

num = np.array ([1, -1.4142*0.4142, 0.4142 ])
den = np.array ([1, 1.4142*0.4142, 0.4142 ])

rf = sig.TransferFunction(num,den)
pretty_print_lti(rf)

    
analyze_sys(rf, 'C')
# Out:
# $\displaystyle \frac{s^2 + s \,\, -0.5858 + 0.4142 }{s^2 + s \,\, 0.5858 + 0.4142 }$

# %% [markdown]
# 2) D:

# %%
#D

# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})


# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti

num = np.array ([1, 0, 16 ])
den = np.array ([1, 1.4142, 1 ])

rf = sig.TransferFunction(num,den)
pretty_print_lti(rf)

    
analyze_sys(rf, 'D')
# Out:
# $\displaystyle \frac{s^2 +  16 }{s^2 + s \,\, 1.414 +   1 }$

# %% [markdown]
# ###### Ejercicio 3:

# %% [markdown]
# Desarrollo algebráico:

# %%
from IPython.display import IFrame
IFrame("./TS5Ej3Final.pdf", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="./TS5Ej3Final.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# - Simulación numérica: módulo, fase, diagrama de polos y ceros y retardo de grupo:

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})


# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti

num = np.array ([0, 6, 0 ])
den = np.array ([1, 6, 4])

rf = sig.TransferFunction(num,den)
pretty_print_lti(rf)

    
analyze_sys(rf, 'D')
# Out:
# /Users/giulianaruffa/opt/anaconda3/lib/python3.9/site-packages/scipy/signal/filter_design.py:1631: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   warnings.warn("Badly conditioned filter coefficients (numerator): the "
# $\displaystyle \frac{s \,\,   6 }{s^2 + s \,\,   6 +   4 }$

# %% [markdown]
# Se verfica el comportamiento de Pasa - banda.
